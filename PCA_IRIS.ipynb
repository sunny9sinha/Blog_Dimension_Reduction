# %% [markdown]
# <a href="https://colab.research.google.com/github/sunny9sinha/Blog_Dimension_Reduction/blob/main/PCA_IRIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris

# Load the Iris dataset
iris = load_iris()
X = iris.data
y = iris.target

# %%
from sklearn.preprocessing import StandardScaler

# Standardize the features
scaler = StandardScaler()
X_std = scaler.fit_transform(X)

# %%
from sklearn.decomposition import PCA

# Create a PCA instance with two principal components
pca = PCA(n_components=2)

# Fit the PCA model to the standardized data
pca.fit(X_std)

# Transform the standardized data onto the first two principal components
X_pca = pca.transform(X_std)

# %%
import matplotlib.pyplot as plt

# Create a scatter plot of the transformed data
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()

# %%
print(pca.explained_variance_ratio_)
# Out:
# [0.72962445 0.22850762]
